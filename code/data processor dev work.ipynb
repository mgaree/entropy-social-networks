# %%
import numpy as np

import model
import entropy
import data_processors as dp
import matplotlib.pyplot as plt

from importlib import reload

# %%
reload(model)

m = model.build_test_model()
m.run_model()
raw_data = m.raw_data

# %%
plt.plot(m.raw_data.T);

# %%
# reload(entropy)
reload(dp)
# Out:
# <module 'data_processors' from 'C:\\Users\\Mike\\Dropbox\\01 Purdue Thesis work\\04 Experimental Study for Paper 2\\code\\data_processors.py'>

# %%
# %time res = dp.process_raw_data_into_entropy_timeseries(raw_data, m.G)
# Out:
# Wall time: 24.7 s

# %%
RV_NUM = 0

plt.plot(res[0:, :, RV_NUM].T);  # with sigma=0.2

# %%
RV_NUM = 0

plt.plot(res[0:, :, RV_NUM].T);  # with sigma=0.05

# %%
RV_NUM = 0

plt.plot(res[0:, :, RV_NUM].T);  # with sigma=0.005

# %%
RV_NUM = 0

plt.plot(res[0:, :, RV_NUM].T);  # with no error term

# %%
# %prun res = dp.process_raw_data_into_entropy_timeseries(raw_data, m.G)
